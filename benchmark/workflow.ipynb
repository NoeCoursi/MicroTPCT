# %% [markdown]
# ### microTPCT workflow

# %% [markdown]
# ## step 0
#
# find X in targets

# %% [markdown]
# ## step 1
#
# aho-corasick/best alignment on all targets -> create a target "fasta" with only [...]

# %% [markdown]
# ## step 2
#
# match on X-regions
#     with Blast -> target fasta with only [X regions]
#     or RegEx -> Basile's kmerisation of X regions
#     or Aho-Corasick -> x20 duplication of X regions

# %% [markdown]
# ## step 3
#
# combine results
